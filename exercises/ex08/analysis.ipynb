# %% [markdown]
# # Analysis for Continuous Improvement
#
# Author Name: `Jonathan Weaver`
#
# 9-digit PID: `730397253`
#
# Continuous Improvement embraces a belief there is _always room to make things better_. It is a mindset and process we value and practice in this course. In this assignment, you are able to practice continuous improvement and contribute to the design ideas of the course.
#
# ## Brainstorming Ideas
#
# Reflect on your personal experiences and observations in COMP110 and **brainstorm modifications to the course that _create value_ beyond its current design**. When brainstorming, try not to be critical of the ideas you come up with regarding scale, stakeholders impacted, or for any other reasons. In the markdown cell below, brainstorm 3 to 5 ideas you think would create value for you.
#
# Each brainstormed idea should state a. the suggested change or addition, b. what the expected value created, and c. which specific stakeholders would benefit.  If helpful, expand on the following template "The course should (state idea here) because it will (state value created here) for (insert stakeholders here)."
#
# Example A: "The course should use only examples from psychology experiments because it will be more relevant for students who are psychology majors."
#
# Example B: "The course should not have post-lesson questions because they are not useful for most students in the class."

# %% [markdown]
# ### Part 1. Creative Ideation
#
# 1. The course should implement more small, low-stake, coding assignments (such as mini exercises) to further build on concepts learned about in class, but with shorter time commitments. This allows for students to practice the concepts covered more thoroughly. As set up, I feel as sometimes the jump from content covered in class to a full exercise is a large one, and this would help close the gap. Students enrolled and prospective students would ideally benefit from this change.
# 2. The course should implement a preclass question form for students to fill out regarding conceptual questions which is then reviewed in the upcoming class. This can both help students who are confused, as well as the professor(s) to gauge student understanding. These questions could be talked about in the first few minutes of class.
# 3. The course should implement quiz corrections for students to complete for 25% credit redemption. These corrections must be thorough and explained and credit will only be granted if both criteria are met. Students could potentially do this for all quizzes or could select two (would need a few trial runs to understand how this affects overall grades and if the 25% redemption needed to be adjusted.) Enrolled and prospective students would benefit from this change, as some people are poor test takers, and all students would benefit from the ability to correct their quiz mistakes, but incentivized by the credit redemption.
# 4. The course should require synchronous attendance every class period. Requiring student attendance will ensure that people are coming to class and learning the concepts covered, thus improving understanding and grades.
# 5. The pace of COMP 110 should be slowed to allow students more time to work with each lesson and build on their knowledge through exercises and other activites. This would benefit prospective students as well as enrolled students. Further, it could allow the professor more time to create mini-exercises and activites.

# %% [markdown]
# ## Connecting with Available Data
#
# The data you have available for this analysis is limited to the anonymized course survey you and your peers filled out a few weeks ago. The data is found in the `survey.csv` file in this exercise directory. Each row represents an individual survey response. Each column has a description which can be found on the project write-up here: <https://22s.comp110.com/exercises/ex08.html>
#
# Review the list of available data and identify which one of your ideas _does not_, or is _least likely to_, have relevant data to support the analysis of your idea to create value. In the box below, identify which of your ideas lacks data and suggest how we might be able to collect this data in the future. One aspect of _continuous improvement_ is trying to avoid "tunnel vision" where possible improvements are not considered because there is no data available to analyze it. Identifying new data sources can unlock improvements!

# %% [markdown]
# ### Part 2. Identifying Missing Data
#
# 1. Idea without sufficient data to analyze: [Idea 2] is likely the hardest one to analyze from the provided data because it's very theoretical. We will not know how this will affect the course perception and student performance until it's implemented. Further, we can very roughly gauge how this would improve COMP 110 based off both `ls_effective` and `lsqs_effective` categories, but because this form is a completely new idea, we would likely only be presented with a rough correlation.
#
# 2. Suggestion for how to collect data to support this idea in the future: A potential way to collect this data is to implement the form, and collect things such as `form_used` which counts how many times the form was used, and `form_perception` which collects student perception of the form (i.e. did they find it helpful?). Both of these would help to support (or not support) the effectiveness and benefit of this idea. We may also find that this form is not helpful, and thus can be disregarded in favor of alternate improvements.

# %% [markdown]
# ## Choosing an Idea to Analyze
#
# Consider those of your ideas which _do_ seem likely to have relevant data to analyze. If none of your ideas do, spend a few minutes and brainstorm another idea or two with the added connection of data available on hand and add those ideas to your brainstormed ideas list.
#
# Select the one idea which you believe is _most valuable_ to analyze relative to the others and has data to support the analysis of. In the markdown cell for Part 3 below, identify the idea you are exploring and articulate why you believe it is most valuable (e.g. widest impact, biggest opportunity for improvement, simplest change for significant improvement, and so on).

# %% [markdown]
# ### Part 3. Choosing Your Analysis
#
# 1. Idea to analyze with available data: The best idea to analyze with the presented data is idea 4 - requiring synchronous attendance each class period.
#
# 2. This idea is more valuable than the others brainstormed because: This idea is more valuable than the others because there is a plethora of data to work with, we can utilize `ls_effective`, `lsqs_effective`, `pace`, `difficulty`, `understanding`, `sync_perf`, `all_sync`, and `flipped_class` to gain insights on if students would prefer to have synchronous aspects of the class required. This would also be the easiest to implement but have widespread impact for all prospective students.

# %% [markdown]
# ## Your Analysis
#
# Before you begin analysis, a reminder that we do not expect the data to support everyone's ideas and you can complete this exercise for full credit even if the data does not clearly support your suggestion or even completely refutes it. What we are looking for is a logical attempt to explore the data using the techniques you have learned up until now in a way that _either_ supports, refutes, or does not have a clear result and then to reflect on your findings after the analysis.
#
# Using the utility functions you created for the previous exercise, you will continue with your analysis in the following part. Before you begin, refer to the rubric on the technical expectations of this section in the exercise write-up.
#
# In this section, you are expected to interleave code and markdown cells such that for each step of your analysis you are starting with an English description of what you are planning to do next in a markdown cell, followed by a Python cell that performs that step of the analysis.

# %% [markdown]
# ### Part 4. Analysis
#
# We begin by changing some settings in the notebook to automatically reload changes to imported files.

# %%
# %reload_ext autoreload
# %autoreload 2

# %% [markdown]
# We continue by importing the helper functions from `data_utils`. Also importing `tabulate` to help display data in a concise table format.

# %%
from data_utils import count, columnar, read_csv_rows, head, select, average
from tabulate import tabulate

# %% [markdown]
# Next, ... (you take it from here and add additional code and markdown cells to read in the CSV file and process it as needed)

# %%
SURVEY_DATA_CSV_FILE_PATH: str = "../../data/survey.csv"

# %% [markdown]
# # Analyzing LS and LSQ Effectiveness
#
# * The first piece of analysis explores the perception of lessons and lesson questions effectiveness. Though broadly related to the overal suggestion to make the course synchronous, understanding if the lessons and lesson questions are effective can help inform the decision to move to all synchronous. For instance, if the questions are percieved to not be helpful, perhaps they can be droped in favor of simply coming to class, or the opposite may occur.

# %%
data_rows: list[dict[str, str]] = read_csv_rows(SURVEY_DATA_CSV_FILE_PATH)
data_cols: dict[str, list[str]] = columnar(data_rows)
selected_data: dict[str, list[str]] = select(data_cols, ["ls_effective", "lsqs_effective"])


ls_effective: dict[str, int] = count(selected_data["ls_effective"])
lsqs_effective: dict[str, int] = count(selected_data["lsqs_effective"])
print(f"LS Effectiveness (1 - 7): {ls_effective}")
print(f"LSQS Effectiveness (1 - 7): {lsqs_effective}")
print(f"Average LSQS Effectiveness: {average(lsqs_effective)}")
# Out:
# LS Effectiveness (1 - 7): {'7': 257, '5': 120, '6': 154, '4': 46, '1': 8, '3': 28, '2': 7}
# LSQS Effectiveness (1 - 7): {'3': 39, '5': 156, '6': 165, '7': 158, '4': 74, '1': 8, '2': 20}
# Average LSQS Effectiveness: 5.382258064516129

# %% [markdown]
# ## A Graphical Representation
# * We've seen the counts of the perception of effectiveness for both LS and LSQS, however they are out of order and hard to see, and it may be helpful to visualize these data in a graphical representation. The next cell will plot the data as a graph.

# %%
from matplotlib import pyplot as plt

fig, axes = plt.subplots(1, 2, figsize=(12, 5), sharey=True)
fig.suptitle("Student Perception of Effectiveness of Lessons and Lesson Questions - COMP 110")


axes[0].set_title("Lessons")
axes[0].bar(ls_effective.keys(), ls_effective.values())
axes[0].tick_params(axis='x', labelrotation = 45)

axes[1].set_title("Lesson Questions")
axes[1].bar(lsqs_effective.keys(), lsqs_effective.values())
# Out:
# <BarContainer object of 7 artists>

# %% [markdown]
# As evidenced by the graph, students, on average, find that lessons are extremely effective, with the majority of ratings being a 7; however, lesson questions are not percieved to be as effective, with many scores ranging in the 5-6 area. This could indicate that lessons questions are not helpful; however, these data are not conclusive.

# %% [markdown]
# # Do Students prefer synchronous lessons, or flipped classrooms?
#
# * This next section of analysis will analyze student perception of flipped classrooms and synchronous aspects of the course. After analyzing this data, there should be thorough insight to whether the course should be moved totally synchronously, as originally recommended. First, getting a preview of the data may be helpful, utilizing the `head` function.

# %%
selected_data1: dict[str, list[str]] = select(data_cols, ["sync_perf", "all_sync"])
data_cols_head: dict[str, list[str]] = head(data_cols, 15)
tabulate(data_cols_head, data_cols_head.keys(), "html")
# Out:
# '<table>\n<thead>\n<tr><th style="text-align: right;">  row</th><th style="text-align: right;">  year</th><th>unc_status                 </th><th>comp_major  </th><th>primary_major                </th><th>data_science  </th><th>prereqs                                                                       </th><th>prior_exp                   </th><th>ap_principles  </th><th>ap_a  </th><th>other_comp                      </th><th>prior_time                  </th><th>languages                                                   </th><th>hours_online_social  </th><th>hours_online_work  </th><th style="text-align: right;">  lesson_time</th><th style="text-align: right;">  sync_perf</th><th style="text-align: right;">  all_sync</th><th style="text-align: right;">  flipped_class</th><th style="text-align: right;">  no_hybrid</th><th style="text-align: right;">  own_notes</th><th style="text-align: right;">  own_examples</th><th style="text-align: right;">  oh_visits</th><th style="text-align:
# ...

# %% [markdown]
# As evidenced by the data preview, it appears that most students do not prefer synchonrous requirements, nor do they believe that it will signifigantly increase performance; however, let's get a clearer view by counting all data points.

# %%
sync_perf: dict[str, int] = count(selected_data1["sync_perf"])
all_sync: dict[str, int] = count(selected_data1["all_sync"])
averages_all_sync: float = average(all_sync)
averages_sync_perf: float = average(sync_perf)
print(f"Synchronous increase performance (1 - 7): {sync_perf}")
print(f"All Synchronous (1 - 7): {all_sync}")
print(f"Averages of All Synchronous Class: {averages_all_sync}")
print(f"Averages of Synchronous Performance: {averages_sync_perf}")
# Out:
# Synchronous increase performance (1 - 7): {'2': 154, '3': 94, '5': 42, '4': 101, '6': 29, '1': 149, '7': 51}
# All Synchronous (1 - 7): {'2': 155, '3': 71, '4': 85, '5': 44, '1': 201, '7': 39, '6': 25}
# Averages of All Synchronous Class: 2.753225806451613
# Averages of Synchronous Performance: 3.0387096774193547

# %% [markdown]
# As we can see from these data, people do not prefer synchronous classes to be enforced, and few people believe that forcing synchronous classes will increase performance, thus indicating that the current hybrid model is effective for most. Low averages of 2.75 and 3.03 for synchronous class and performance, respectively, support this statement.

# %% [markdown]
# ## A Graphical Representation
# * Once again, viewing this information in a graph will be helpful, so a graph is constructed below.

# %%
fig, axes = plt.subplots(1, 2, figsize=(12, 5), sharey=True)
fig.suptitle("Student Perception of Synchronous Performance and Required Synchronous Class")


axes[0].set_title("Synchronous Performance")
axes[0].bar(sync_perf.keys(), sync_perf.values())
axes[0].tick_params(axis='x', labelrotation = 45)

axes[1].set_title("Required Synchronous Class")
axes[1].bar(all_sync.keys(), all_sync.values())
# Out:
# <BarContainer object of 7 artists>

# %% [markdown]
# As evidenced by the graphs, students seem to stronly appose synchronous class, and very few students believe that this would increase performance in the course, thus it would likley not be ideal to require all synchronous components of the class, and instead continue to offer a hybrid model.

# %% [markdown]
# ## Flipped Preference?
#
# * To further explore student preference for a flipped classroom (which would reqiure synchronous aspects) or the current hybrid model, it is helpful to analyze the `flipped_class` category. This will further help us understand what is working and what is not.

# %%
selected_data2: dict[str, list[str]] = select(data_cols, ["flipped_class"])
flipped: dict[str, int] = count(selected_data2["flipped_class"])
flipped_avg: float = average(flipped)

print(f"Flipped Classroom Preference: {flipped}")
print(f"Average Rating: {flipped_avg}")
# Out:
# Flipped Classroom Preference: {'1': 177, '2': 127, '3': 95, '5': 61, '6': 39, '7': 38, '4': 83}
# Average Rating: 2.988709677419355

# %% [markdown]
# ## Flipped Analysis
#
# * As evidence by the data above, people strongly disagree that they would want the classroom to be flipped, and watch videos over the weekend to prepare for required synchronous classes. The average rating of 2.9 further shows this.

# %% [markdown]
# # Difficulty and Understanding
#
# * The final piece of key analysis involves the perception of difficulty level and understanding. Both of these are necessary to make informed decisions about the direction of the class. This next code will present the average difficulty ratings as well as the understanding rating.

# %%
selected_data3: dict[str, list[str]] = select(data_cols, ["difficulty", "understanding"])
difficulty: dict[str, int] = count(selected_data3["difficulty"])
understanding: dict[str, int] = count(selected_data3["understanding"])

difficulty_avg: float = average(difficulty)
understanding_avg: float = average(understanding)

print(f"Difficulty Average: {difficulty_avg}")
print(f"Understanding Average: {understanding_avg}")
# Out:
# Difficulty Average: 4.383870967741935
# Understanding Average: 4.95483870967742

# %% [markdown]
# ## Conclusion
#
# In the following markdown cell, write a reflective conclusion given the analysis you performed and identify recommendations.
#
# If your analysis of the data supports your idea, state your recommendation for the change and summarize the data analysys results you found which support it. Additionally, describe any extensions or refinements to this idea which might be explored further. Finally, discuss the potential costs, trade-offs, or stakeholders who may be negatively impacted by this proposed change.
#
# If your analysis of the data is inconclusive, summarize why your data analysis results were inconclusive in the support of your idea. Additionally, describe what experimental idea implementation or additional data collection might help build more confidence in assessing your idea. Finally, discuss the potential costs, trade-offs, or stakeholders who may be negatively impacted by experimenting with your idea.
#
# Finally, if your analysis of the data does not support it, summarize your data analysis results and why it refutes your idea. Discuss the potential costs, trade-offs, or stakeholders who may be negatively impacted by this proposed change. If you disagree with the validity of the findings, describe why your idea still makes sense to implement and what alternative data would better support it. If you agree with the validity of the data analysis, describe what alternate ideas or extensions you would explore instead.

# %% [markdown]
# ### Part 5. Conclusion
#
# The data analysis performed in this notebook is conclusive - the suggested improvement to require synchronous lectures was not supported. Student prefernce clearly indicates that this would not be a desirable change and instead the current hybrid model may be improved instead. To be consise, it is most helpful to look at the average ratings as follows:
#
# (1 - 7 Scale; 7 Being most desirable or most agreed with)
# * Flipped Classroom Support: 2.98
# * Required Synchronous Class: 2.75
# * Synchronous Class Increase Performance: 3.03
# * Average LSQS Effectiveness: 5.38
#
# As evidenced by these data, people strongly opposed required synchronous classes and further, do not believe that requiring them to be synchronous will increase performance.
#
# I do, however, raise slight questions when observing both the difficulty and understanding categories of data. Students report the following:
#
# (1 - 7 Scale; 7 Being most challenging and most understanding)
# * Difficulty Average: 4.38
# * Understanding Average: 4.95
#
# Students report that the class is moderately difficult at a 4.38; yet report a understanding value of about 5. This understanding value is high (roughly 2 points away from a 7); yet the difficulty value also remains high. I would expect that with a large understanding value, the difficulty value would decrease as the values should be inversely proportional (as you understand the content more, the challenge of said content should decrease.)
#
# I acknowledge, however, some limitations in these numbers. The average calculation does not account for outlier data and so having multiple people clustered at a 1 or 7 will affect the data in the upward or downward direction, when in reality most people are clustered from the 3.5 - 6 range.
#
# As a result of these calculations and analyses; I have arrived at the following presumptions and conclusions:
# * Students prefer the hybrid model, this offers flexibility pacing which is beneficial to the majority of students. It would be ill-advised to change this format of the course as this would affect current and prospective students.
# * Students do not believe that requiring synchronous lectures will increase performance. As a result, asynchronous Tuesday classes should be kept, and Thursday classes should be considered to be kept as hybrid, continuing to offer the remote livestream option as a semi-synchronous option.
# * Students percieve the course to be challenging. It would be recommended to implement more small-scale exercises in addition to LSQS. LSQS effectivness was rated as 5.38. I believe that to increase effectiveness, small-scale and low stake assignments should be incorporated (such as mini-exercises). This, ideally, should decrease difficulty and increase student understanding. This assignments should be required and for a grade (as a motivator for completion)
#
# Though my original suggestion was proven to be a poor one, this analysis still proves helpful. We have learned that the format of the course in current, is desirable and on average, students understand the content. Valid extensions and ideas to explore would be as follows:
# * Implementing mini-exercises, and requestioning people on understanding, difficulty, and a new category: `mini_EX_effectiveness`. This would give us a good idea as to if the exercises are proving helpful.
# * Follow-up regarding the LSQS effectivness. Why are students not finding these effective? Is there a different strategy we should approach. Potential data to collect as followes: Did you like the format of LSQS? Preferred Question Format: MC, FRQ, etc.
